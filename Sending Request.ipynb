# %%
import json,requests

# %%
url = "http://4fa2d0695394.ngrok.io/"
req = requests.get(url)
print(req.status_code)
# Out:
# 200

# %%
data = {"Review":"this movie is worst movie I saw ."}
data = json.dumps(data)


x = requests.post(url+'/get_sentiment',data)
print(x.status_code)
print(x.text)
# Out:
# 200
# {"result":"neg"}

# %%
data = {"Review":"Katrina was looking great ."}
data = json.dumps(data)


x = requests.post(url+'/get_sentiment',data)
print(req.status_code)
print(x.text)
# Out:
# 200
# {"result":"pos"}

# %% [markdown]
# **Predict from EC2 instance**

# %%
import json,requests
url = "http://34.239.249.13:5000/"
data = {"Review":"this movie is worst movie I saw ."}
data = json.dumps(data)


x = requests.post(url+'/get_sentiment',data)
print(x.text)
# Out:
# {
#   "result": "neg"
# }
